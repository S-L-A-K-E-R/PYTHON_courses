# %% [markdown]
# # 002 - Getting started with Python

# %% [markdown]
# ## <u>A.</u> What is a REPL-structured program?

# %% [markdown]
# <img src="https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/refs/heads/main/COURSES/002_Getting-Started/ASSETS/REPL%20-%20Banner.png" height="500">

# %% [markdown]
# For most of your work on these notebooks (or on your .py files), you are going to use a "REPL" structure:
#
# 1. **<ins>R</ins>ead**: get some data... most of the time `FROM THE USER`
# 2. **<ins>E</ins>valuate**: do some calculation, conditionnal operations... whatever, that's the whole process of the algorithm!
# 3. **<ins>P</ins>rint**: display the result to the user.
# 4. **<ins>L</ins>oop**: repeat the whole operation.
#
# (TOWRITE) We're going to use mostly REPL structure for a long time in these notebooks and py files.
# Up until we reach project level exercises!
#
# It's fitting for specific or specialized exercises.

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ## <u>B.</u> Variables

# %% [markdown]
# Variables are what we use just like in maths. A variable can take whatever value, and we will use it for further uses.
#
# Ideally, variables are set with a value from the user, so it allows infinite uses with our program.

# %% [markdown]
# What might be different from other programming languages:
#
# > In Python, when you're declaring a variable there is NO NEED to set its type.\
# > Python automatically will decide what is the best type to use for it.

# %%
# ID: an integer (int) value (id ∈ N)
id = 4

# Name: a string (a list of characters)
display_text = "Hello, I'm currently learning Python!"

# %%
# Now that these variables exist, I can use them whenever I want...!

print("Value of id =", id)
print("Blabla")

print(display_text)

# %% [markdown]
# For those who really love stricter programming language (like C, Rust...), you can set the type of a variable. It's a "**TYPING**".
#
# If you really want to decide of a set type for a variable, you can follow this:
#
# ``` text
# variable_name: TYPE
# ```

# %%
# book_name (string)
book_name: str = "Odyssey by Homer"

# id_book (integer (∈ N))
book_year_release: int
book_year_release = -800

# %% [markdown]
# Now, in this code snippet above, the variables are sure to be set with these defined types... FOR NOW.
#
# Actually, we will see that soon enough, but variables in Python are highly versatile and are just references linked to object... but more on that later.

# %%
# Remember how "book_year_release" was an INT?
book_year_release = "-800 before C."


print( book_year_release )
# Out:
# -800 before C.

# %% [markdown]
# As you can see, the typing isn't forever! You can change it's type easily, and the code will adapt for you.
#
# So convenient, thanks Python!

# %% [markdown]
# Please refrain yourself from using TOO MUCH typing when not required.
# Typing should only be used in specific conditions. When we get there, you will be reminded of using them during the course.
#
#
# What makes Python an incredible language is the fact that it's an extremely readable and easy programming language to use, with small to no restrictions, especially compared to other programming languages.
#
# Also, as you can see in the example above, variable typing isn't static. Thus, it's mostly for indicating the type to programmers.

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ## <u>C.</u> **COMMENTS** in Python

# %% [markdown]
# Adding comments to your code is extremely useful for every other programmers that might stumble upon your code... or even for your future self, because you will definitely forget your own code 3 days after writing it.
#
# Comments are used to keep small or medium documentation about the behavior of your code.
# They are really useful for explaning hard snippet of code that aren't easy to understand at first glimpse.

# %% [markdown]
# ### 1. Single line comment

# %% [markdown]
# In Python, you can use `#` to comment small snippet of code.

# %%
# A Python single-line comment is done using "#"

print("hey!") # A comment can be put anywhere! But everything after the #... won't be read.

#print("Test?")
# ^ This won't run, because the "#" is in front of the command.

# %% [markdown]
# ### Multi-line comments:

# %% [markdown]
# For having a whole area of text, for describing functions, or adding more texts to your source code...\
# You can use the quote symbol `""" (...) """` like so:
#
# ``` python
# # v these """ quotes.
# """
# Comment line N.1
# Line N.2
# (...)*
#
# I could keep going, until I reach the latest quote (").
# """
# # ^ these """ quotes.
#
# ```

# %%
print("Cookie...")

"""
If you want to have multiple lines of comments...
You can do so using the quote (") character *three times* (x2).

The text inside the (") won't be read by the program.
"""

print("and Milk!")
# Out:
# Cookie...
# and Milk!

# %% [markdown]
# This code should only run the 2 `print(...)` function calls.
#
# If so, we have successfully created comments in our code. :)

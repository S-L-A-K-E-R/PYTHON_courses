# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/refs/heads/chore/001-intro-asset-links/COURSES/001_Intro/ASSETS/PYTHON_banner_chapter.png)

# %% [markdown]
# # **ADVANCED PYTHON** *(with Google Colab)*
#
# For this course, we will mainly use **Google Colab** to write and run Python code.
#
# Google Colab is quite different from the programming environments you may have used before, especially if you are coming from **C programming** or other similar compiled programming languages.
#
# Instead of working mainly with `.c` source files and executables, Colab uses a **Notebook** format.
#
# <br>
#
# ---

# %% [markdown]
# ## What is a Notebook, and how does it work?
#
# A Notebook is divided into **cells**.
#
# There are mainly two types of cells:
#
# * **Code cells**, where you write and execute Python code.
# * **Text cells**, where you can write explanations, titles, instructions, notes, equations, links, etc.
#
# What you are reading right now... is a **text cell**!
#
# <br>
#
# > Text cells are very useful for organizing a Notebook into different sections and explaining what each part of your code is supposed to do.
#
# <br>
#
# ---

# %% [markdown]
# ## Text Cells and Markdown

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/MD_Banner.png)

# %% [markdown]
# Try creating your own **Text Cell** now!
#
# <br>
#
# You can create as many as you want, move them around afterward, and use them to organize your Notebook into clear sections.
#
# When you move your mouse pointer between or below cells, two options should appear:

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/COLAB_add.png)

# %% [markdown]
# **+ Code** → creates a new Python code cell\
# **+ Text** → creates a new text cell

# %% [markdown]
# ---
#
# ### What is Markdown?
#
# Text Cells use a formatting language called **Markdown**.\
# Markdown is not a programming language: it is a **lightweight markup language** used to format text in a simple and readable way.
#
# It is extremely common on the Internet. You can find Markdown in places such as:
#
# * GitHub `README.md` files
# * technical documentation
# * forums and messaging platforms
# * Jupyter Notebooks
# * Google Colab
#
# <br>
#
# Instead of using buttons to format everything, you write small symbols directly into the text.
#
# <br>
#
# For example you can create different **levels of headings**.
#
# ```text
# # Main title
# ## Subtitle
# ### Smaller subtitle
# ```
#
# <br>

# %% [markdown]
# #### **Formatting in Markdown**

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/COLAB_editing.png)

# %% [markdown]
# You can format text:
#
# ```text
# **bold text**
# *italic text*
# `code`
# ```
#
# which gives:
#
# + **bold text**
# + *italic text*
# + `code`
#
# <br>
#
# You can also create code snippet using ` ``` ` surrounding your code in the cell:
# ```python
# number = 42
# print(number)
# ```
# Note that you cannot run code in *Text Cells*.

# %% [markdown]
# #### **Lists in Markdown**
#
# You can easily create unordered lists using `-`, `+`, or `*`:
#
# ```text
# - Python
# - C
# - Java
# ```
#
# or numbered lists:
#
# ```text
# 1. First step
# 2. Second step
# 3. Third step
# ```
#
# <br>

# %% [markdown]
# #### **Links in Markdown**
#
#
# You can also create clickable [links](https://google.com/):
#
# ```text
# [Google Colab](https://colab.research.google.com/)
# ```
#
# The structure is:
#
# ```text
# [Text displayed](URL)
# ```
#
# <br>

# %% [markdown]
# You don't need to learn every Markdown feature right now.
#
# <br>
#
# For this course, knowing how to create **titles, bold/italic text, lists, links, and inline code** will already be more than enough.
#
# You will naturally learn more Markdown as you use Notebooks throughout the semester.
#
# <br>
#
# If you want to learn more about Markdown in Google Colab, I highly recommend you to **check this cheat sheet**:\
# [Cheat Sheet (Google Colab MD)](https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Cheat_sheet_for_Google_Colab.ipynb)
#
# <br>
#
# ---

# %% [markdown]
# ## Running code cells

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/PYTHON_banner_chapter.png)

# %% [markdown]
# Now, it's time to get into Python programming.
#
# Try running the **Code Cell** below:

# %%
print("This is a Code Cell!")
print("You can execute me with the arrow on the left.")

print("The output of the code should display right below this line.")
# Out:
# This is a Code Cell!
# You can execute me with the arrow on the left.
# The output of the code should display right below this line.

# %% [markdown]
# Unlike a traditional program, you do not necessarily have to execute the entire Notebook at once.\
# You can run **one cell at a time**, whenever you want.
#
# When you execute a cell, only the code contained inside that cell is executed.
#
# <br>
#
# For example, you could first run a cell containing:

# %%
# Creating a variable:
my_number = 42

# %% [markdown]
# And then, even in other code cells, you can call this newly created variable for the whole notebook.

# %%
# Using the variable in a new cell:
print("Value of the variable:")
print(my_number)
# Out:
# Value of the variable:
# 42

# %% [markdown]
# The second cell will still know the value of `my_number`.
#
# <br>
#
# This is because Colab keeps a **running Python session** in memory.
#
# Variables, imported libraries, functions, classes, and other objects you create remain available until the runtime is restarted or disconnected.
#
# <br>

# %% [markdown]
# At any time on your notebook you can see what **variables are actually active** when you executed code.
#
# At the bottom of the notebook, down-left of the screen, you can click on the `{} Variables` icon.

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/COLAB_bottom.png)

# %% [markdown]
# This will open a new tab on the notebook:

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/COLAB_variable-table.png)

# %% [markdown]
# ⚠️ Because of this, **the order in which you execute cells matters!**
#
# Sometimes a Notebook may appear to work simply because you previously executed another cell. This is one of the important things to keep in mind when working with notebooks.

# %% [markdown]
# ---

# %% [markdown]
# ## Running the entire Notebook
#
# If you prefer something closer to the usual programming workflow, you can also execute **all the cells from top to bottom**.
#
# Google Colab provides an option to run the entire Notebook automatically.

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/COLAB_runtime-all.png)

# %% [markdown]
# <br>
#
# This is also a good way to check that your Notebook really works from a clean beginning and does not accidentally depend on cells you executed earlier.
#
# <br>
#
# ⚠️ **Before submitting your work:** restart the runtime and run every cell from top to bottom.\
# Your Notebook must work without relying on anything previously stored in memory.
#
# <br>
#
# ---

# %% [markdown]
# ## Where is the code actually running?
#
# When using Google Colab, your Python code is usually **not running directly on your computer**.
#
# Google provides you with a remote runtime: essentially, a temporary computer hosted on Google's servers that executes your Python code.
#
# During your session, this runtime keeps things such as:
#
# * your variables,
# * your imported libraries,
# * your functions and classes,
# * and temporary files created during execution.
#
# However, keep in mind that this environment is **temporary**.
#
# If the runtime is restarted or disconnected, its memory and temporary files may disappear. Important files should therefore be saved somewhere persistent, such as Google Drive or your own computer.
#
# ---

# %% [markdown]
# # Running Notebooks locally: Jupyter

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/JNB_banner.png)

# %% [markdown]
# Google Colab is based on the same general Notebook philosophy as another very popular tool:
#
# **Jupyter Notebook**
#
# <br>
#
# Jupyter can be installed and run directly on your computer.
#
# Interestingly, even though it runs locally, its interface usually opens inside your **web browser** using a local address.\
# The experience is therefore quite similar to Google Colab.
#
# <br>
#
# The main difference is where your code runs:
#
# **Google Colab → Google's remote servers**\
# **Jupyter Notebook → your own computer (locally run)**
#
# <br>
#
# Both approaches have advantages.
#
# Colab is extremely convenient because there is almost nothing to install, while running Python locally gives you more control over your environment, files, libraries, and computing resources.
#
# ---

# %% [markdown]
# # What if you don't like Notebooks?
#
# No problem! You can absolutely write Python using a more traditional development environment such as **Visual Studio Code**.
#
# In that case, your project may look more familiar if you are coming from C or any other programming language.
#
# <br>
#
# For example:
#
# ```text
# my_project/
# │
# ├── main.py
# ├── functions.py
# └── data/
#     ├── input_1.csv
#     └── input_2.txt
# ```
#
# Instead of executing individual cells, you usually run a Python file such as:
#
# ```text
# main.py
# ```
#
# Python will then execute its instructions from top to bottom.
#
# <br>
#
# **Visual Studio Code** is an excellent choice if you want to work on larger Python projects or simply prefer a more traditional programming environment.
#
# You can find the official Python setup tutorial for VS Code here:\
# https://code.visualstudio.com/docs/python/python-tutorial
#
# ---

# %% [markdown]
# # What will we use during this semester?
#
# Unless stated otherwise:
#
# > **Google Colab will be the main environment used for labs and homework submissions during this course**.
#
# <br>
#
# This gives everyone a similar working environment and makes it easier to share
# and review your work.
#
# However, you are completely free to use **VS Code or another Python environment while developing your programs**.
#
# Just make sure that the version you submit also works correctly in Google Colab when Colab is requested.
#
# <br>
#
# ---

# %% [markdown]
# # Going further: Anaconda

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/anaconda_banner.png)

# %% [markdown]
# If you later work with **Data Science, scientific computing, Machine Learning, or data visualization**, you may encounter **Anaconda**.
#
# Anaconda is a Python distribution that provides Python together with many tools and libraries commonly used for scientific and data-oriented work.
#
# It also provides tools for managing Python environments and packages.
#
# <br>
#
# Among the applications often associated with Anaconda, you may encounter tools such as **Jupyter Notebook** and **Spyder**.
#
# <br>
#
# You can find it here:\
# https://www.anaconda.com/download
#
#
# <br>
#
# Here you can have a preview of the Anaconda Navigator:

# %% [markdown]
# ![Anaconda screenshot.webp](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/anaconda_screenshot.webp)

# %% [markdown]
# For those of you interested in *scientific computing*, or more generally in working with and *analyzing data*, **Spyder** can also be a great tool to try!

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/S-L-A-K-E-R/PYTHON_courses/main/COURSES/001_Intro/ASSETS/spyder_IDE.webp)

# %% [markdown]
# ---

# %% [markdown]
# # In short
#
# <br>
#
# <div align="left">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/9/9b/Google_Colab_pic.png?utm_source=en.wikipedia.org&utm_campaign=index&utm_content=original" width="70"><br>
# </div>
#
# **Google Colab**\
# → Notebook interface\
# → Runs mainly on Google's servers\
# → Almost nothing to install\
# → Very convenient for labs, exercises and sharing
#
# <br>
#
# <br>
#
# <div align="left">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/250px-Jupyter_logo.svg.png?utm_source=fr.wikipedia.org&utm_campaign=index&utm_content=thumbnail" width="70"><br>
# </div>
#
#
# **Jupyter Notebook**\
# → Notebook interface\
# → Can run locally on your computer\
# → More control over your local environment
#
# <br>
#
# <br>
#
# <div align="left">
#     <img src="https://thumb.wikimedia.org/wikipedia/commons/thumb/9/9a/Visual_Studio_Code_1.35_icon.svg/960px-Visual_Studio_Code_1.35_icon.svg.png?utm_source=fr.wikipedia.org&utm_campaign=index&utm_content=thumbnail" width="70"><br>
# </div>
#
# **Visual Studio Code**\
# → Traditional programming environment\
# → Excellent for larger Python projects\
# → Similar workflow to what you may already know from C or other students with more classic IDE experience.
#
# <br>
#
# <br>
#
# <div align="left">
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPvApjsauxungpUkgw6mbSP8k18B1OXwKGLN7D8_YYcMR8DAuJj9o4JFj_&s=10" width="70"><br>
# </div>
#
# **Anaconda**\
# → Python distribution and environment-management ecosystem\
# → Particularly common in Data Science and scientific Python
#
# <br>

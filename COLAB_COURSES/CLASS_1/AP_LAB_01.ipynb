# %% [markdown]
# <a href="https://colab.research.google.com/github/Celeste-VANDAMME/advanced_python_course/blob/main/COLAB_COURSES/CLASS_1/AP_LAB_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LAB 1** - MarkDown & Basic codes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This **Lab #1** will teach you how to **use Google Colab notebooks properly**, understand how they behave, and avoid some of the **common mistakes** you may encounter while working with them.
#
# <br>
#
# If you run into any difficulties during the lab, everything you need can be found in the **Introduction course material (Class #1)**.

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ## **Exercise 1** — Holiday biography...

# %% [markdown]
# You have been tasked to write about what you have done during your summer holidays (shortly!).
#
# Although, it's requested of you to add these **mandatory elements** in your biography:
#
# 1. A `Main Title` of your holiday
# 2. At least one `Subtitle`
# 3. A few paragraphs
# 4. One `bold` word
# 5. One `italic` sentence
# 6. One piece of `inline` code (can be used to highlight words)
# 7. A `bullet list` with 3 elements in it (can be an ordered list too)
# 8. A clickable `link` to a related website of your choice.
#
# <br>
#
# **BONUS :** make it into 3 different text cells.
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ## **Exercise 2** — Small coding steps

# %% [markdown]
# For this exercise, we expect you to run different CODE CELLS.
#
# <br>
#
# 1. In a first code cell, create **two variables** like these:
# ``` text
# (STRING)   student_name     = "Elisa"
# (INTEGER)  favorite_number  = 42
# ```
# You can replace the value with *something else*.
#
# <br>
#
# 2. In a second cell, display them with `print(...)`.
#
# <br>
#
# 3. Open the `{} Variables panel` in Colab and verify that both variables are currently stored in memory.
#
# <br>
#
# Screenshot the variable table and paste the screenshot into a new text cell.\
# What happens when you do so?

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ## **Exercise 3** — Order matters

# %% [markdown]
# Notebooks behave differently from traditional IDEs.
#
# The order in which you run each cell is important. This exercise should emphasize it.
#
# <br>

# %%
# CELL [A]
number = 15

# %%
# CELL [B]
print(number)

# %%
# CELL [C]
number = 35

# %% [markdown]
# Here are some instructions for you.
#
# ``` text
# Run the cells: [A] → [B].
# ```
# What is displayed?

# %% [markdown]
# ``` text
# Run the cells: [C] → [B].
# ```
#
# What changed?\
# Explain what happened.

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ## **Exercise 4** — Runtime break

# %% [markdown]
# This time, you will have to expose the risk of the memory while executing a Notebook. This can naturally happens when your server cluster go down after some inactivity on Colab.
#
# <br>
#
# 1. **Run** the cell code below:

# %%
# Cell [A]

# Create a variable:
pi      = 3.14
radius  = 12

# %% [markdown]
# Now the variables are available in the notebook.
#
# <br>
#
# 2. **Restart the runtime** on Colab, in the tab: `Runtime > Restart session`.

# %%
# Cell [B]

# Calculate a value:
perimeter = 2*pi*radius
print("2.π.r =", perimeter)

# %% [markdown]
# Run the `cell [B]` again.
#
# <br>
#
# What happens?\
# What are the variables available in the `{} Variables` tab in Colab when you restart the runtime?

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ## **Exercise 5** — The final test: *Restart & Run All*

# %% [markdown]
# > **REMINDER:** When submitting your lab online for correction, you should make sure the whole Notebook runs without any compiling errors.
#
#
# <br>
#
# Before submitting this notebook: restart your notebook and run all the cells.\
# Everything should be running from top to bottom (this avoids having running order issues).
#
# You can do so easily in the tab `Runtime > Restart session and run all`
#
# <br>
#
# Your notebook must execute without syntax or runtime errors.\
# If it fails, you must find which cell isn't working.

# %%
 # FIX THIS CODE
# (so your whole notebook runs properly...!)

length = 5
width = 6

area = lenght * withd

print("Area =", area_square)

# %% [markdown]
# If you see this kind of warning:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The "NameError" at the bottom should tell you more about is going wrong in your code.
#
# Also, all the red-underlined code segment are easy spot to fix.

# %% [markdown]
# <br>
#
# ---
